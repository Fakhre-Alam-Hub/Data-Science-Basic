# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
dir(iris)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target', 'target_names']

# %%
iris.data[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
iris.feature_names[:5]
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
iris.target_names[:]
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
X = iris.data[:,:4]
y = iris.target

X_sepal_length = X[:,0] 
X_sepal_width = X[:,1]
X_petal_length = X[:,2]
X_petal_width = X[:,3]

# %%
plt.figure(1, figsize=(10,8))
plt.title("sepal_length Vs sepal_width", fontsize = 14)
plt.xlabel('X_sepal_length', fontsize=12)
plt.ylabel('X_sepal_width', fontsize=12)
plt.scatter(X_sepal_length,X_sepal_width, marker='+', c=y, s=80, cmap=plt.cm.Set1)

plt.figure(2, figsize=(10,8))
plt.title("petal_length Vs petal_width", fontsize = 14)
plt.xlabel('X_petal_length', fontsize=12)
plt.ylabel('X_petal_width', fontsize=12)
plt.scatter(X_petal_length,X_petal_width, marker='x', c=y, s=80, cmap=plt.cm.Set1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=10)

# %%
from sklearn.linear_model import LogisticRegression

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.9473684210526315

# %%
y_predicted = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_predicted, y_test)
cm
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  2, 12]], dtype=int64)

# %%
import seaborn as sns

sns.heatmap(cm, annot=True)
plt.xlabel('y-test (actual value)', fontsize=12)
plt.ylabel('y-predicted (predicted value)', fontsize=12)
# Out:
# Text(33.0, 0.5, 'y-predicted (predicted value)')

# %%
X_test = pd.DataFrame(X_test)
X_test.columns = ['sepal length', 'sepal width', 'petal length', 'petal width']
X_test.head()
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           6.3          2.3           4.4          1.3
# 1           6.4          2.7           5.3          1.9
# 2           5.4          3.7           1.5          0.2
# 3           6.1          3.0           4.6          1.4
# 4           5.0          3.3           1.4          0.2

# %%
predicted = pd.DataFrame(model.predict(X_test))
predicted.columns = ['predicted']
predicted.head()
# Out:
#    predicted
# 0          1
# 1          2
# 2          0
# 3          1
# 4          0

# %%
df = pd.concat([X_test, predicted], axis='columns')
df.tail()
# Out:
#     sepal length  sepal width  petal length  petal width  predicted
# 33           5.8          2.8           5.1          2.4          2
# 34           6.3          2.5           5.0          1.9          2
# 35           4.6          3.2           1.4          0.2          0
# 36           6.7          3.3           5.7          2.1          2
# 37           6.9          3.2           5.7          2.3          2

# %%
def flower():
    f = []
    for i in range(38):
        if df.predicted[i]==0:
            f.append('setosa')
        elif df.predicted[i]==1:
            f.append('versicolor')
        else:
            f.append('verginica')
    return f

flower = pd.DataFrame(flower())

# %%
flower.columns = ['target_names']

# %%
output = pd.concat([df, flower], axis='columns')

# %%
output
# Out:
#     sepal length  sepal width  petal length  petal width  predicted  \
# 0            6.3          2.3           4.4          1.3          1
# 1            6.4          2.7           5.3          1.9          2
# 2            5.4          3.7           1.5          0.2          0
# 3            6.1          3.0           4.6          1.4          1
# 4            5.0          3.3           1.4          0.2          0
# 5            5.0          2.0           3.5          1.0          1
# 6            6.3          2.5           4.9          1.5          1
# 7            5.8          2.7           4.1          1.0          1
# 8            5.1          3.4           1.5          0.2          0
# 9            5.7          2.8           4.5          1.3          1
# 10           5.6          3.0           4.5          1.5          2
# 11           5.8          2.7           5.1          1.9          2
# 12           5.5          2.3           4.0          1.3          1
# 13           4.9          3.0           1.4          0.2          0
# 14           5.1          3.8           1.5          0.3          0
# 15           6.8          3.0           5.5          2.1          2
# 16           6.0          3.4           4.5          1.6          2
# 17           4.4          3.0           1.3          0.2          0
# 18           5.1          3.7           1.5          0.4          0
# 19           5.0          3.2           1.2          0.2          0
# 20           7.1          3.0           5.9          2.1          2
# 21           6.4          2.8           5.6          2.2          2
# 22           6.2          2.8           4.8          1.8          2
# 23           4.8          3.4           1.9          0.2          0
# 24           5.9          3.0           4.2          1.5          1
# 25           4.7          3.2           1.3          0.2          0
# 26           5.7          3.0           4.2          1.2          1
# 27           5.5          2.6           4.4          1.2          1
# 28           6.8          2.8           4.8          1.4          1
# 29           7.7          3.8           6.7          2.2          2
# 30           6.6          2.9           4.6          1.3          1
# 31           6.2          2.9           4.3          1.3          1
# 32           7.2          3.0           5.8          1.6          2
# 33           5.8          2.8           5.1          2.4          2
# 34           6.3          2.5           5.0          1.9          2
# 35           4.6          3.2           1.4          0.2          0
# 36           6.7          3.3           5.7          2.1          2
# 37           6.9          3.2           5.7          2.3          2
#
#    target_names
# 0    versicolor
# 1     verginica
# 2        setosa
# 3    versicolor
# 4        setosa
# 5    versicolor
# 6    versicolor
# 7    versicolor
# 8        setosa
# 9    versicolor
# 10    verginica
# 11    verginica
# 12   versicolor
# 13       setosa
# 14       setosa
# 15    verginica
# 16    verginica
# 17       setosa
# 18       setosa
# 19       setosa
# 20    verginica
# 21    verginica
# 22    verginica
# 23       setosa
# 24   versicolor
# 25       setosa
# 26   versicolor
# 27   versicolor
# 28   versicolor
# 29    verginica
# 30   versicolor
# 31   versicolor
# 32    verginica
# 33    verginica
# 34    verginica
# 35       setosa
# 36    verginica
# 37    verginica
